# %% [markdown]
# # Atividade de Análise de dados
# Feito por Gabriel Ribeiro, dia 12/05
# ### Vamos começar observando nossa base de dados

# %%
import pandas as pd

df = pd.read_csv("fornecedores.csv")
df
# Out:
#        Id                CNPJ             CPF  \
# 0       1  00.000.000/0001-91             NaN
# 1       4  00.000.028/0001-29             NaN
# 2       5  00.000.155/0001-28             NaN
# 3       6  00.000.166/0001-08             NaN
# 4       8  00.000.208/0001-00             NaN
# ..    ...                 ...             ...
# 495  1023  00.105.032/0001-51             NaN
# 496  1025  00.105.137/0001-00             NaN
# 497  1029                 NaN  ***.063.000-**
# 498  1030  00.106.386/0001-10             NaN
# 499  1032                 NaN  ***.065.590-**
#
#                                                   Nome Ativo  Recadastrado  \
# 0                                   BANCO DO BRASIL SA   Sim           NaN
# 1                TARGET ENGENHARIA E CONSULTORIA LTDA.   Sim           NaN
# 2                  COUPLING SERVICO DE MANUTENCAO LTDA   Não           NaN
# 3                               IRMAOS RODOPOULOS LTDA   Sim           NaN
# 4                             BRB BANCO DE BRASILIA SA   Sim           NaN
# ..                                                 ...   ...           ...
# 495                      MP PURIFICADORES DE AGUA LTDA   Sim           NaN
# 496                             WEISSHEIMER & CIA LTDA   Não           NaN
# 497                              HELENA ZANELLA PRATES   Sim           NaN
# 498  COMPAGER - LOGISTICA, TRANSPORTES E ARMAZENS G...   Sim           NaN
# 499                                   CRISTIANO STRECK   Sim           NaN
#
#                 Município  UF                 Natureza Jurídica  \
# 0         97012: BRASÍLIA  DF    9: SOCIEDADE DE ECONOMIA MISTA
# 1        71072: São Paulo  SP  2: SOCIEDADE EMPRESÁRIA LIMITADA
# 2        71072: São Paulo  SP  2: SOCIEDADE EMPRESÁRIA LIMITADA
# 3         97012: BRASÍLIA  DF  2: SOCIEDADE EMPRESÁRIA LIMITADA
# 4         97012: BRASÍLIA  DF    9: SOCIEDADE DE ECONOMIA MISTA
# ..                    ...  ..                               ...
# 495  81051: Florianópolis  SC  2: SOCIEDADE EMPRESÁRIA LIMITADA
# 496    88412: Santa Maria  RS  2: SOCIEDADE EMPRESÁRIA LIMITADA
# 497        87912: Pelotas  RS                               NaN
# 498       76678: Londrina  PR  2: SOCIEDADE EMPRESÁRIA LIMITADA
# 499      88633: São Borja  RS                               NaN
#
#     Porte da Empresa  Ramo do Negócio  Unidade Cadastradora  \
# 0            2: null              NaN                   NaN
# 1            2: null              NaN                   NaN
# 2            2: null              NaN                   NaN
# 3            2: null              NaN                   NaN
# 4            2: null              NaN                   NaN
# ..               ...              ...                   ...
# 495          2: null              NaN                   NaN
# 496          2: null              NaN                   NaN
# 497  1: MICROEMPRESA              NaN                   NaN
# 498          2: null              NaN                   NaN
# 499  1: MICROEMPRESA              NaN                   NaN
#
#                                                   CNAE  CNAE Secundário  \
# 0    6422100: BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL              NaN
# 1    6203100: DESENVOLVIMENTO E LICENCIAMENTO DE PR...              NaN
# 2    3314701: MANUTENÇÃO E REPARAÇÃO DE MÁQUINAS MO...              NaN
# 3                     4120400: CONSTRUÇÃO DE EDIFÍCIOS              NaN
# 4    6422100: BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL              NaN
# ..                                                 ...              ...
# 495  4753900: COMÉRCIO VAREJISTA ESPECIALIZADO DE E...              NaN
# 496  4731800: COMÉRCIO VAREJISTA DE COMBUSTÍVEIS PA...              NaN
# 497                                                NaN              NaN
# 498  4930202: TRANSPORTE RODOVIÁRIO DE CARGA, EXCET...              NaN
# 499                                                NaN              NaN
#
#     Habilitado a Licitar
# 0                    Sim
# 1                    Sim
# 2                    Sim
# 3                    Sim
# 4                    Sim
# ..                   ...
# 495                  Sim
# 496                  Sim
# 497                  Sim
# 498                  Sim
# 499                  Sim
#
# [500 rows x 15 columns]
